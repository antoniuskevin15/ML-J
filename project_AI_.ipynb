# %%
from keras.models import Sequential
from keras.layers import Dense
import pandas as pd


# load the dataset
# dataset = pd.read_csv('pima-indians-diabetes.csv')
dataset = pd.read_csv("COVID-19.csv")
dataset.head()
# Out:
#   iso               country        date  \
# 0  AE  United Arab Emirates  2020-02-15
# 1  AE  United Arab Emirates  2020-02-16
# 2  AE  United Arab Emirates  2020-02-17
# 3  AE  United Arab Emirates  2020-02-18
# 4  AE  United Arab Emirates  2020-02-19
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# 1                                                4.0
# 2                                                1.0
# 3                                                1.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                 5.0
# 1                                 4.0
# 2                                 5.0
# 3                                 5.0
# 4                                 4.0
#
#    residential_percent_change_from_baseline  \
# 0                                       1.0
# 1                                       1.0
# ...

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# 2022-11-22 19:50:43.118216: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # New section

# %%
average = 0
for i in range(10):
  # fit the keras model on the dataset
  # model.fit(X, y, epochs=150, batch_size=10)
  model.fit(X, y, epochs=150, batch_size=10, verbose = 0)

  # evaluate the keras model
  # _, accuracy = model.evaluate(X, y)
  _, accuracy = model.evaluate(X, y, verbose = 0)

  # penggunaan verbose = 0 --> digunakan untuk menghapus tampilan proses Epoch
  print('Iteration %02d --> Accuracy: %.2f' % (i+1,accuracy*100))
  average += accuracy

print("Average of 10 Accuracies : %.2f" % (average*10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 2>()
#       1 average = 0
#       2 for i in range(10):
#       3   # fit the keras model on the dataset
#       4   # model.fit(X, y, epochs=150, batch_size=10)
# ----> 5   model.fit(X, y, epochs=150, batch_size=10, verbose = 0)
#       7   # evaluate the keras model
#       8   # _, accuracy = model.evaluate(X, y)
#       9   _, accuracy = model.evaluate(X, y, verbose = 0)
#
# NameError: name 'X' is not defined

# %%
count = 0
status = ""
# make class predictions with the model
predictions = (model.predict(X) > 0.5).astype(int)

print("|\t\t\tData\t\t\t\t|Prediksi|Data Asli|Status|")
print("-----------------------------------------------------------------------------------")
# summarize predictions
for i in range(768):
	if y[i]==predictions[i]:
		status = "True"
		count += 1
	else:
		status = "False"
	# print('|%s \t|    %d   |    %d    |%5s |' % (X[i].tolist(), predictions[i], y[i], status))
	# untuk melihat hasil, maka dapat dicetak seluruh data dan nilai yang diprediksi

print('From The Total of 30 Datas, Correct Predictions is %d'% (count))
print('Accuracy by System : %.2f' % (accuracy*100))
print('Accuracy by Calculation : %.2f' % ((count*100)/768))
# Out:
# |			Data				|Prediksi|Data Asli|Status|
# -----------------------------------------------------------------------------------
# From The Total of 30 Datas, Correct Predictions is 632
# Accuracy by System : 82.29
# Accuracy by Calculation : 82.29

# %%
data = loadtxt("data1.txt", delimiter=",")
# print(data)
X_new = data[:,0:8]
# y_new = data[:,8]
# # print(new_list)
# print(X_new)
# print(y_new)

# %%
data = loadtxt("data1.txt", delimiter=",")
X_new = data[:,0:8]
print("|\t\t\tData\t\t\t\t|Prediksi|")

# prediksi data tanpa diketahui orang diabetes atau tidak
prediksi = (model.predict(X_new) > 0.5).astype(int)
for i in range(30):
  	print('|%s \t|    %d   |' % (X_new[i].tolist(), prediksi[i]))
# Out:
# |			Data				|Prediksi|
# |[1.0, 160.0, 80.0, 30.0, 0.0, 24.22, 0.347, 19.0] 	|    0   |
# |[3.0, 134.0, 77.0, 27.0, 154.0, 23.79, 0.492, 47.0] 	|    1   |
# |[1.0, 133.0, 102.0, 28.0, 140.0, 32.8, 0.234, 45.0] 	|    0   |
# |[3.0, 173.0, 82.0, 48.0, 465.0, 38.4, 2.137, 25.0] 	|    1   |
# |[0.0, 118.0, 64.0, 23.0, 89.0, 0.0, 1.731, 21.0] 	|    0   |
# |[0.0, 84.0, 64.0, 22.0, 66.0, 35.8, 0.545, 21.0] 	|    0   |
# |[2.0, 90.0, 62.0, 18.0, 59.0, 25.1, 1.268, 25.0] 	|    0   |
# |[2.0, 122.0, 52.0, 43.0, 158.0, 36.2, 0.816, 28.0] 	|    0   |
# |[12.0, 140.0, 82.0, 43.0, 325.0, 39.2, 0.528, 58.0] 	|    1   |
# |[0.0, 98.0, 82.0, 15.0, 84.0, 25.2, 0.299, 22.0] 	|    0   |
# |[1.0, 116.0, 72.0, 12.0, 87.0, 22.1, 0.463, 37.0] 	|    0   |
# |[4.0, 100.0, 66.0, 29.0, 196.0, 32.0, 0.444, 42.0] 	|    0   |
# |[0.0, 93.0, 100.0, 39.0, 72.0, 43.4, 1.021, 35.0] 	|    0   |
# |[1.0, 107.0, 72.0, 30.0, 82.0, 30.8, 0.821, 24.0] 	|    0   |
# ...
